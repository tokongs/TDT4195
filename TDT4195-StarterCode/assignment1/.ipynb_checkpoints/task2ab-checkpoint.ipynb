# %%
import matplotlib.pyplot as plt
import pathlib
import numpy
from utils import read_im, save_im
output_dir = pathlib.Path("image_solutions")
output_dir.mkdir(exist_ok=True)

# %%
im = read_im(pathlib.Path("images", "lake.jpg"))
plt.imshow(im)

# %% [markdown]
# ## Task 2a

# %%
def greyscale(im):
    """ Converts an RGB image to greyscale
    
    Args:
        im ([type]): [np.array of shape [H, W, 3]]
    
    Returns:
        im ([type]): [np.array of shape [H, W]]
    """
    
    redWeight = 0.212
    greenWeight = 0.7152
    blueWeight = 0.722

    return numpy.array([[redWeight*y[0] + greenWeight*y[1] + blueWeight*y[2] for y in x] for x in im])

# %%
im_greyscale = greyscale(im)
save_im(output_dir.joinpath("lake_greyscale.jpg"), im_greyscale, cmap="gray")
plt.imshow(im_greyscale, cmap="gray")
# Out:
# Warning: The dynamic range of the image is [0.011639215686274509, 1.5784392156862743] normalizing to [-1, 1]

# %% [markdown]
# ## Task 2b

# %%
def inverse(im):
    """ Finds the inverse of the greyscale image
    
    Args:
        im ([type]): [np.array of shape [H, W]]
    
    Returns:
        im ([type]): [np.array of shape [H, W]]
    """
    return numpy.array([[1 - val for val in x] for x in im])

# %%
im_inverse = inverse(im)
print(im_inverse)
plt.imshow(im_inverse, cmap="gray")
# Out:
# [[[0.70196078 1.         0.69803922]
#   [0.75686275 1.         0.67058824]
#   [0.9372549  1.         0.75294118]
#   ...
#   [0.4627451  0.95294118 0.64705882]
#   [0.45490196 0.90588235 0.64313725]
#   [0.51372549 0.94509804 0.70588235]]
#
#  [[0.54509804 0.89411765 0.78431373]
#   [0.41176471 0.63529412 0.56862745]
#   [0.49803922 0.56078431 0.55686275]
#   ...
#   [0.28235294 0.32156863 0.18431373]
#   [0.26666667 0.28235294 0.18431373]
#   [0.36078431 0.35686275 0.28627451]]
#
#  [[0.63529412 0.94117647 1.        ]
#   [0.35686275 0.5372549  0.73333333]
#   [0.40392157 0.42352941 0.6745098 ]
#   ...
#   [0.5254902  0.13333333 0.18039216]
#   [0.52941176 0.12941176 0.21176471]
#   [0.6627451  0.2627451  0.35686275]]
#
#  ...
#
#  [[0.64313725 0.98823529 0.93333333]
#   [0.61568627 0.94509804 0.89411765]
#   [0.63529412 0.94901961 0.90588235]
#   ...
#   [0.60784314 0.24705882 0.29019608]
#   [0.37647059 0.29803922 0.43529412]
#   [0.25490196 0.47843137 0.65490196]]
#
#  [[0.64705882 0.98431373 0.93333333]
#   [0.61568627 0.9372549  0.89019608]
#   [0.63921569 0.94117647 0.90196078]
#   ...
#   [0.62745098 0.28627451 0.32156863]
#   [0.39607843 0.33333333 0.47843137]
#   [0.2745098  0.51372549 0.69019608]]
#
#  [[0.66666667 0.99607843 0.94509804]
#   [0.62745098 0.94901961 0.90196078]
#   [0.64705882 0.94901961 0.90980392]
#   ...
#   [0.58823529 0.24313725 0.29019608]
#   [0.36470588 0.30980392 0.45098039]
#   [0.25490196 0.49803922 0.68235294]]]
